# %%
print("Hello world")
# Out:
# Hello world

# %%
("Hello world")
# Out:
# 'Hello world'

# %% [markdown]
# List

# %%
numbers=[1,2,3,4,"ram"]
numbers
# Out:
# [1, 2, 3, 4, 'ram']

# %%
numbers[-2]
# Out:
# 4

# %%
numbers.append(6)
numbers
# Out:
# [1, 2, 3, 4, 'ram', 6]

# %%
numbers.remove(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 'ram']

# %%
numbers.remove('ram')
numbers
# Out:
# [1, 2, 3, 4]

# %%
a=[5,4,9,8]
a.sort()
print(a)
# Out:
# [4, 5, 8, 9]

# %%
squares=[num**2 for num in range(0,10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# Dictionaries

# %%
color={'rojo':'red',2:'two','verde':'green'}
color
# Out:
# {'rojo': 'red', 2: 'two', 'verde': 'green'}

# %%
color['rojo']
# Out:
# 'red'

# %%
color[3]="black"
color
# Out:
# {'rojo': 'red', 2: 'two', 'verde': 'green', 3: 'black'}

# %%
color[2]='yellow'
color
# Out:
# {'rojo': 'red', 2: 'yellow', 'verde': 'green', 3: 'black'}

# %% [markdown]
# Tuple

# %%
numbers = (1,2,3,4,5)
numbers
# Out:
# (1, 2, 3, 4, 5)

# %%
numbers[2]
# Out:
# 3

# %%
numbers[-1]
# Out:
# 5

# %%
a = (1,2,3,2,2,5)

a.count(2)
# Out:
# 3

# %%
len(a)
# Out:
# 6
